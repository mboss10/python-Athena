# %% [markdown]
# ## Exploratory work to query Athena

# %%
pip install "SQLAlchemy>=1.0.0"
# Out:
# Requirement already satisfied: SQLAlchemy>=1.0.0 in /Users/max/anaconda3/lib/python3.10/site-packages (1.4.39)
# Requirement already satisfied: greenlet!=0.4.17 in /Users/max/anaconda3/lib/python3.10/site-packages (from SQLAlchemy>=1.0.0) (2.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install --upgrade 'sqlalchemy<2.0'
# Out:
# Collecting sqlalchemy<2.0
#   Downloading SQLAlchemy-1.4.52.tar.gz (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 21.5 MB/s eta 0:00:0000:0100:01
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: greenlet!=0.4.17 in /Users/max/anaconda3/lib/python3.10/site-packages (from sqlalchemy<2.0) (2.0.1)
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py) ... done
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.4.52-cp310-cp310-macosx_10_9_x86_64.whl size=1570353 sha256=128085e09f4546eb9a2104de0407e910f9bd3bdf585d0a30615e0d417b45a829
#   Stored in directory: /Users/max/Library/Caches/pip/wheels/5b/c9/56/2651d3da186ab1cd7e86cd7f9c174e465dd0ccaa926248bbc8
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.28
#     Uninstalling SQLAlchemy-2.0.28:
#       Successfully uninstalled SQLAlchemy-2.0.28
# Successfully installed sqlalchemy-1.4.52
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import func, select
from sqlalchemy.engine import create_engine
from sqlalchemy.sql.schema import Table, MetaData

conn_str = "awsathena+rest://{aws_access_key_id}:{aws_secret_access_key}@athena.{region_name}.amazonaws.com:443/"\
           "{schema_name}?s3_staging_dir={s3_staging_dir}"
engine = create_engine(conn_str.format(
    aws_access_key_id="[we enter our access key here]",
    aws_secret_access_key="[we enter our secret key here]",
    region_name="[we enter the AWS server region here - east1, west2, etc ...]",
    schema_name="[we enter our database schema here]",
    s3_staging_dir="[we enter our S3 bucket here - s3://our_bucket/"]))

# %%
import pandas as pd

events_df = pd.read_sql("SELECT * FROM events", engine)
events_df
# Out:
#    _hoodie_commit_time    _hoodie_commit_seqno _hoodie_record_key  \
# 0    20240228221523821   20240228221523821_0_0   7426_0x742600002
# 1    20240228221523821   20240228221523821_0_1   7334_0x733400002
# 2    20240228221523821   20240228221523821_0_2   7482_0x748200002
# 3    20240228221523821   20240228221523821_0_3   6851_0x685100002
# 4    20240228221523821   20240228221523821_0_4   7160_0x716000002
# 5    20240228221523821   20240228221523821_0_5   7427_0x742700002
# 6    20240228221523821   20240228221523821_0_6   7159_0x715900002
# 7    20240228221523821   20240228221523821_0_7   7062_0x706200002
# 8    20240228221523821   20240228221523821_0_8   7162_0x716200002
# 9    20240228221523821   20240228221523821_0_9   7577_0x757700002
# 10   20240228221523821  20240228221523821_0_10   7098_0x709800002
# 11   20240228221523821  20240228221523821_0_11   6929_0x692900002
# 12   20240228221523821  20240228221523821_0_12   6800_0x680000002
# 13   20240228221523821  20240228221523821_0_13   7075_0x707500002
# 14   20240228221523821  20240228221523821_0_14   6852_0x685200002
# 15   20240228221523821  20240228221523821_0_15   7161_0x716100002
# 16   20240228221523821  20240228221523821_0_16   7001_0x700100002
# 17   20240228221523821  20240228221523821_0_17   7428_0x742800002
# 18   20240228221523821  20240228221523821_0_18   7112_0x711200002
# 19   20240228221523821  20240228221523821_0_19   7024_0x702400002
# 20   20240228221523821  20240228221523821_0_20   7321_0x732100002
# 21   20240228221523821  20240228221523821_0_21   6850_0x685000002
# 22   20240228221523821  20240228221523821_0_22   7016_0x701600002
# 23   20240228221523821  20240228221523821_0_23   6801_0x680100002
# 24   20240221205951075   20240221205951075_0_0   2047_0x204700002
# 25   20240226220837375   20240226220837375_0_1   2048_0x204800002
#
#    _hoodie_partition_path                                  _hoodie_file_name  \
# 0         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 1         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 2         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 3         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 4         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 5         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 6         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 7         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 8         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 9         accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 10        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 11        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 12        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 13        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 14        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 15        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 16        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 17        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 18        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 19        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 20        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 21        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 22        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 23        accountCode=565  f0f7ad60-9f02-43cf-8328-1570483c6798-0_0-37-43...
# 24        accountCode=617  61fa9c9b-5baa-4160-8d0c-05e43e7d5895-0_0-37-43...
# 25        accountCode=617  61fa9c9b-5baa-4160-8d0c-05e43e7d5895-0_0-37-43...
#
#      _id            startdate eventstatuslabel                    timezone  \
# 0   7426  2023-01-21 06:00:00      unpublished  Central Time (US & Canada)
# 1   7334  2022-11-06 07:00:00        published  Pacific Time (US & Canada)
# 2   7482  2023-03-19 07:00:00        published  Pacific Time (US & Canada)
# 3   6851  2021-11-07 04:00:00      unpublished  Eastern Time (US & Canada)
# 4   7160  2022-09-11 04:00:00      unpublished  Eastern Time (US & Canada)
# 5   7427  2023-02-26 05:00:00      unpublished  Eastern Time (US & Canada)
# 6   7159  2022-09-11 07:00:00      unpublished                     Arizona
# 7   7062  2022-04-24 04:00:00      unpublished  Eastern Time (US & Canada)
# 8   7162  2022-11-06 04:00:00      unpublished  Eastern Time (US & Canada)
# 9   7577  2023-04-02 04:00:00        published  Eastern Time (US & Canada)
# 10  7098  2023-04-02 06:00:00      unpublished             Central America
# 11  6929  2022-01-23 07:00:00      unpublished                     Arizona
# 12  6800  2021-09-26 05:00:00      unpublished  Central Time (US & Canada)
# 13  7075  2022-05-15 04:00:00      unpublished  Eastern Time (US & Canada)
# 14  6852  2021-11-07 07:00:00      unpublished  Pacific Time (US & Canada)
# 15  7161  2022-10-02 07:00:00      unpublished  Pacific Time (US & Canada)
# 16  7001  2022-02-27 05:00:00      unpublished  Eastern Time (US & Canada)
# 17  7428  2023-02-26 05:00:00      unpublished  Eastern Time (US & Canada)
# 18  7112  2022-06-05 07:00:00      unpublished  Pacific Time (US & Canada)
# 19  7024  2022-04-10 04:00:00      unpublished  Eastern Time (US & Canada)
# 20  7321  2022-11-06 07:00:00      unpublished  Pacific Time (US & Canada)
# 21  6850  2021-10-03 04:00:00      unpublished  Eastern Time (US & Canada)
# 22  7016  2022-03-27 04:00:00      unpublished  Eastern Time (US & Canada)
# 23  6801  2022-09-11 04:00:00      unpublished  Eastern Time (US & Canada)
# 24  2047  2024-01-13 05:00:00        published  Eastern Time (US & Canada)
# 25  2048  2024-02-25 05:00:00        published  Eastern Time (US & Canada)
#
#    timezonemapping  ... _month _day        primarykey       _primarykey  \
# 0             None  ...     02   28  7426_0x742600002  7426_0x742600002
# 1             None  ...     02   28  7334_0x733400002  7334_0x733400002
# 2             None  ...     02   28  7482_0x748200002  7482_0x748200002
# 3             None  ...     02   28  6851_0x685100002  6851_0x685100002
# 4             None  ...     02   28  7160_0x716000002  7160_0x716000002
# 5             None  ...     02   28  7427_0x742700002  7427_0x742700002
# 6             None  ...     02   28  7159_0x715900002  7159_0x715900002
# 7             None  ...     02   28  7062_0x706200002  7062_0x706200002
# 8             None  ...     02   28  7162_0x716200002  7162_0x716200002
# 9             None  ...     02   28  7577_0x757700002  7577_0x757700002
# 10            None  ...     02   28  7098_0x709800002  7098_0x709800002
# 11            None  ...     02   28  6929_0x692900002  6929_0x692900002
# 12            None  ...     02   28  6800_0x680000002  6800_0x680000002
# 13            None  ...     02   28  7075_0x707500002  7075_0x707500002
# 14            None  ...     02   28  6852_0x685200002  6852_0x685200002
# 15            None  ...     02   28  7161_0x716100002  7161_0x716100002
# 16            None  ...     02   28  7001_0x700100002  7001_0x700100002
# 17            None  ...     02   28  7428_0x742800002  7428_0x742800002
# 18            None  ...     02   28  7112_0x711200002  7112_0x711200002
# 19            None  ...     02   28  7024_0x702400002  7024_0x702400002
# 20            None  ...     02   28  7321_0x732100002  7321_0x732100002
# 21            None  ...     02   28  6850_0x685000002  6850_0x685000002
# 22            None  ...     02   28  7016_0x701600002  7016_0x701600002
# 23            None  ...     02   28  6801_0x680100002  6801_0x680100002
# 24            None  ...     02   14  2047_0x204700002  2047_0x204700002
# 25            None  ...     02   26  2048_0x204800002  2048_0x204800002
#
#      _messagetype _requesttimestamp        domain    pkeventid  accountcode  \
# 0   EVENT_MESSAGE     1709078629000  stagingawstp  0x742600002          565
# 1   EVENT_MESSAGE     1709078629000  stagingawstp  0x733400002          565
# 2   EVENT_MESSAGE     1709078629000  stagingawstp  0x748200002          565
# 3   EVENT_MESSAGE     1709078629000  stagingawstp  0x685100002          565
# 4   EVENT_MESSAGE     1709078629000  stagingawstp  0x716000002          565
# 5   EVENT_MESSAGE     1709078629000  stagingawstp  0x742700002          565
# 6   EVENT_MESSAGE     1709078629000  stagingawstp  0x715900002          565
# 7   EVENT_MESSAGE     1709078629000  stagingawstp  0x706200002          565
# 8   EVENT_MESSAGE     1709078629000  stagingawstp  0x716200002          565
# 9   EVENT_MESSAGE     1709078629000  stagingawstp  0x757700002          565
# 10  EVENT_MESSAGE     1709078629000  stagingawstp  0x709800002          565
# 11  EVENT_MESSAGE     1709078629000  stagingawstp  0x692900002          565
# 12  EVENT_MESSAGE     1709078629000  stagingawstp  0x680000002          565
# 13  EVENT_MESSAGE     1709078629000  stagingawstp  0x707500002          565
# 14  EVENT_MESSAGE     1709078629000  stagingawstp  0x685200002          565
# 15  EVENT_MESSAGE     1709078629000  stagingawstp  0x716100002          565
# 16  EVENT_MESSAGE     1709078629000  stagingawstp  0x700100002          565
# 17  EVENT_MESSAGE     1709078629000  stagingawstp  0x742800002          565
# 18  EVENT_MESSAGE     1709078629000  stagingawstp  0x711200002          565
# 19  EVENT_MESSAGE     1709078629000  stagingawstp  0x702400002          565
# 20  EVENT_MESSAGE     1709078629000  stagingawstp  0x732100002          565
# 21  EVENT_MESSAGE     1709078629000  stagingawstp  0x685000002          565
# 22  EVENT_MESSAGE     1709078629000  stagingawstp  0x701600002          565
# 23  EVENT_MESSAGE     1709078629000  stagingawstp  0x680100002          565
# 24  EVENT_MESSAGE     1707940874000  stagingawstp  0x204700002          617
# 25  EVENT_MESSAGE     1708983296000  stagingawstp  0x204800002          617
#
#     partition_accountcode
# 0                     565
# 1                     565
# 2                     565
# 3                     565
# 4                     565
# 5                     565
# 6                     565
# 7                     565
# 8                     565
# 9                     565
# 10                    565
# 11                    565
# 12                    565
# 13                    565
# 14                    565
# 15                    565
# 16                    565
# 17                    565
# 18                    565
# 19                    565
# 20                    565
# 21                    565
# 22                    565
# 23                    565
# 24                    617
# 25                    617
#
# [26 rows x 64 columns]

# %%
regs_df = pd.read_sql("SELECT * FROM registrations", engine)

len(regs_df)
# Out:
# 796

# %%
#generate a random sample of n regs
registrations_sample = regs_df.sample(n=5)
registrations_sample
# Out:
#     _hoodie_commit_time     _hoodie_commit_seqno    _hoodie_record_key  \
# 41    20240221205953711   20240221205953711_0_41  registrationCode:316
# 615   20240221205953711  20240221205953711_0_615  registrationCode:299
# 616   20240221205953711  20240221205953711_0_616  registrationCode:695
# 715   20240221205953711  20240221205953711_0_715  registrationCode:755
# 32    20240221205953711   20240221205953711_0_32   registrationCode:24
#
#     _hoodie_partition_path                                  _hoodie_file_name  \
# 41         accountCode=617  7c2ac6df-144d-4b4e-b800-859a7cfdbc9b-0_0-40-44...
# 615        accountCode=617  7c2ac6df-144d-4b4e-b800-859a7cfdbc9b-0_0-40-44...
# 616        accountCode=617  7c2ac6df-144d-4b4e-b800-859a7cfdbc9b-0_0-40-44...
# 715        accountCode=617  7c2ac6df-144d-4b4e-b800-859a7cfdbc9b-0_0-40-44...
# 32         accountCode=617  7c2ac6df-144d-4b4e-b800-859a7cfdbc9b-0_0-40-44...
#
#      _id                                            profile  \
# 41   316  {_messagetype=PROFILE_MESSAGE, _requesttimesta...
# 615  299  {_messagetype=PROFILE_MESSAGE, _requesttimesta...
# 616  695  {_messagetype=PROFILE_MESSAGE, _requesttimesta...
# 715  755  {_messagetype=PROFILE_MESSAGE, _requesttimesta...
# 32    24  {_messagetype=PROFILE_MESSAGE, _requesttimesta...
#
#                   datecreated              datemodified  \
# 41   2023-12-15T14:48:07.314Z  2024-02-18T12:26:19.043Z
# 615  2023-12-15T14:48:07.314Z  2024-02-18T12:26:19.036Z
# 616  2023-12-18T14:48:07.314Z  2024-02-18T12:29:06.584Z
# 715  2023-12-27T14:48:07.314Z  2024-02-18T12:31:00.483Z
# 32   2023-12-02T14:48:07.314Z  2024-02-18T12:06:54.801Z
#
#            datestatusmodified  ...   _pkeventid     _primarykey  \
# 41   2023-12-15T14:48:07.314Z  ...  0x204700002  316_1708287979
# 615  2023-12-15T14:48:07.314Z  ...  0x204700002  299_1708287979
# 616  2023-12-18T14:48:07.314Z  ...  0x204700002  695_1708288147
# 715  2023-12-27T14:48:07.314Z  ...  0x204700002  755_1708288260
# 32   2023-12-02T14:48:07.314Z  ...  0x204700002   24_1708286815
#
#          primarykey     _source          _messagetype  _requesttimestamp  \
# 41   316_1708287979  Touchpoint  REGISTRATION_MESSAGE      1708287979000
# 615  299_1708287979  Touchpoint  REGISTRATION_MESSAGE      1708287979000
# 616  695_1708288147  Touchpoint  REGISTRATION_MESSAGE      1708288147000
# 715  755_1708288260  Touchpoint  REGISTRATION_MESSAGE      1708288260000
# 32    24_1708286815  Touchpoint  REGISTRATION_MESSAGE      1708286815000
#
#            domain    pkeventid  accountcode  partition_accountcode
# 41   stagingawstp  0x204700002          617                    617
# 615  stagingawstp  0x204700002          617                    617
# 616  stagingawstp  0x204700002          617                    617
# 715  stagingawstp  0x204700002          617                    617
# 32   stagingawstp  0x204700002          617                    617
#
# [5 rows x 51 columns]

# %%
registrations_sample.index
# Out:
# Int64Index([41, 615, 616, 715, 32], dtype='int64')

# %%
for index in registrations_sample.index:
    print(f'index: {index}')
    print(registrations_sample["datecreated"][index])
# Out:
# index: 41
# 2023-12-15T14:48:07.314Z
# index: 615
# 2023-12-15T14:48:07.314Z
# index: 616
# 2023-12-18T14:48:07.314Z
# index: 715
# 2023-12-27T14:48:07.314Z
# index: 32
# 2023-12-02T14:48:07.314Z
